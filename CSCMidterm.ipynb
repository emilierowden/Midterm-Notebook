# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/ColabNotebooks/winequality-red.csv")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-2815f5bb02e3> in <module>()
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("/content/drive/MyDrive/ColabNotebooks/winequality-red.csv")
#       3 df
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df.plot.scatter(x = 'quality', y = 'citric acid')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.stripplot(data=df, x='quality', y='citric acid', jitter=0.5)
plt.xlabel('Quality')
plt.ylabel("Citric Acid")
plt.title("Citric Acid vs Quality Distribution")
# Out:
# Text(0.5, 1.0, 'Citric Acid vs Quality Distribution')

# %%
sns.lineplot(data=df, x='free sulfur dioxide', y='total sulfur dioxide')
plt.xlabel('Free sulfur dioxide')
plt.ylabel("Total sulfur dioxide")
plt.title("Total sulfur dioxide vs Free sulfur dioxide")
# Out:
# Text(0.5, 1.0, 'Total sulfur dioxide vs Free sulfur dioxide')

# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv('/content/drive/MyDrive/winequality-red.csv')

# %%
sns.ecdfplot(data=df, x='alcohol', hue='residual sugar', legend=False)

# %%
sns.displot(df['alcohol'], kind='kde' )
sns.displot(df['residual sugar'], kind='kde' )

# %%
sns.displot(data=df, x='alcohol', hue='residual sugar', kind='kde', legend=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)

# %%
import matplotlib.pyplot as plt
import pandas as pd
  
df = pd.read_csv("/content/drive/MyDrive/winequality-red.csv")



  
X = list(df.iloc[:, 0])
Y = list(df.iloc[:,8])
  

plt.bar(X, Y, color='b')
plt.title("")
plt.xlabel("fixed acidity")
plt.ylabel("Ph")

plt.hist(16, rwidth=0.2)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
  
df = pd.read_csv("/content/drive/MyDrive/winequality-red.csv")
x= ('fixed acidity')
y= ('pH')

  
# adding labels
#df.set_xlabel('pH')
#df.set_xlabel('fixed acidity')
plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True

labels = ['pH', 'Citric Acid']
sizes = [23, 45, 12, 20]
#colors = ['Orange', 'Blue', ]
plt.hist(df, color = 'Red','Blue',)
plt.legend(patches, labels, loc="best")

plt.hist(df[x])

plt.hist(df[y])
plt.show()
# Out:
#   File "<ipython-input-22-2491f5e58a7f>", line 20
#     plt.hist(df, color = 'Red','Blue',)
#                               ^
# SyntaxError: positional argument follows keyword argument

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

  
df = pd.read_csv("/content/drive/MyDrive/winequality-red.csv")
x=  ('fixed acidity')
y= ('pH')
plt.hist(df[x], label='fixed acidity', alpha=.7, color='blue')
plt.hist(df[y], label='pH', alpha=.5,color='orange')

plt.legend()     
plt.show()
